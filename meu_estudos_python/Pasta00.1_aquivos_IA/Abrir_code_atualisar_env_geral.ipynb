# %% [markdown]
# # 2️⃣ Atualizar o YAML sempre que mudar
# ## Quando instalar novas libs importantes:

# %%
conda env export --from-history > ~/Python_Projects/ambientes_conda/geral.yml

# %% [markdown]
# # Assim o arquivo geral.yml sempre reflete a versão mais recente do seu ambiente.

# %% [markdown]
# # 3️⃣ Integrar com o VS Code
# Assim o arquivo geral.yml sempre reflete a versão mais recente do seu ambiente.
# Abra o VS Code dentro do diretório do projeto, por exemplo:

# %%
code ~/Python_Projects/estudos/estudo_curso_em_video

# %% [markdown]
# # No VS Code:
#
# Pressione Ctrl+Shift+P
#
# Digite e escolha: “Python: Select Interpreter”
#
# Escolha o ambiente:
#
# /home/lunix/anaconda3/envs/geral/bin/python
#
#
# ✅ Pronto! Agora o VS Code usará seu ambiente Conda “geral” automaticamente para rodar scripts, notebooks, ou debugar código.

# %% [markdown]
# # ✅ Então, o comando certo é:
#
# ## Primeiro, ative seu ambiente:
#
# conda activate geral
#
#
# ## Depois instale Pillow (substituto moderno do PIL):
#
# ### Opção 1 — via Conda (recomendado)
# conda install -c conda-forge pillow
#
#
#
# ### Opção 2 — via pip (também funciona)
# pip install pillow
